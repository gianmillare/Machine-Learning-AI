# %% [markdown]
# # Xception - CNN Architecture
#
# Remember that every pretrained model used from Keras comes with a required image_size. Check the documentation.
#
# [Xception Documentation](https://keras.io/api/applications/xception/)
# [VGG19 Documentation](https://keras.io/api/applications/vgg/#vgg19-function)

# %%
# Step 1: import documentation
# %matplotlib inline
import matplotlib.pyplot as plt

import os
import numpy as np
import tensorflow as tf

# keras related dependencies
import keras
from keras.preprocessing import image
from keras.applications.xception import (Xception, preprocess_input, decode_predictions)

# %%
# Step 2: load the Xception model
model = Xception(weights='imagenet')

# %%
# Step 3: Load in the image to predict using the dimensions defined in the documentation
img = image.load_img(os.path.join("images", "pup.jpg"), target_size=(299, 299))
plt.imshow(img)

# %%
# Step 4: preprocess the image to get ready for the model
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Step 5: Make the prediction
print(decode_predictions(model.predict(x), top=3)[0])
plt.imshow(img)
# Out:
# [('n02085936', 'Maltese_dog', 0.76741976), ('n02098286', 'West_Highland_white_terrier', 0.019817086), ('n02098413', 'Lhasa', 0.011307018)]

# %%
# Step 6: Now that we know the model works, refactor it into a function to make it recallable
def predict_pic(image_path):
    """ Using Xception to label an image """
    img = image.load_img(image_path, target_size=(299, 299))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    print(decode_predictions(model.predict(x), top=3)[0])
    plt.imshow(img)

# %%
# Test the model
predict_pic(os.path.join("images", "kitten.jpg"))
# Out:
# [('n02123045', 'tabby', 0.50506765), ('n02123159', 'tiger_cat', 0.31741804), ('n02124075', 'Egyptian_cat', 0.10078595)]
