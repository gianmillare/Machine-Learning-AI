# %% [markdown]
# # Introduction to Kmeans
#
# Finding the center of a cluster of data points. That center acts as a classifier for new data points. Data that satisfy the criteria to be in that cluster (depending on its distance from the 'center') gets labeled similar to that center.
#
# The objective here is to build a model using KMeans structuring so that when a new data point is introduced, that data would be thrown into the KMeans model and then classified.
#
# By moving the center around, the labels for the data points will change depending on the distance between the data points and the center.

# %%
# Step 1: Import Dependencies

# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
# Step 2: Get the Data

data, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
# Visualizing the data

plt.scatter(data[:, 0], data[:, 1])

# %%
# As shown above, n_clusters = 4 is the k-value (4)
# Step 3: After determining the number of centers, using KMeans as a classifier

kmeans = KMeans(n_clusters=4)

# %%
# Step 4: Fit (train) the data

kmeans.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
# Step 5: use the trained data to make predictions

predicted_clusters = kmeans.predict(data)

# %%
# Step 6: Plot (visualize the data to see if the model accurately classified the points)
# This acts as validation that the model works
plt.scatter(data[:, 0], data[:, 1], c=predicted_clusters, s=50, cmap='viridis')
